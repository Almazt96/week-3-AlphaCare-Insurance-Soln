# %%
# 4. Model Comparison
# Objective: Evaluate multiple models to identify the best one.
# Metrics: F1, precision, recall. Use transformers evaluation tools.

# 5. Interpretability
# Objective: Implement SHAP or LIME for model explanation.
# Libraries/Tools: shap, lime.

# %pip install shap
# %pip install shap

import shap

# Use a sample text
sample_text = "ምርት ከአዲስ ቤተማር እና ብር እንዲቆርብ።"
explainer = shap.Explainer(model, tokenizer)
shap_values = explainer([sample_text])

# Visualize
shap.plots.text(shap_values[0])
# Out:
# Collecting shap
#   Using cached shap-0.46.0.tar.gz (1.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\almazt\appdata\local\programs\python\python313\lib\site-packages (from shap) (2.0.0)
# Requirement already satisfied: scipy in c:\users\almazt\appdata\local\programs\python\python313\lib\site-packages (from shap) (1.14.1)
# Requirement already satisfied: scikit-learn in c:\users\almazt\appdata\local\programs\python\python313\lib\site-packages (from shap) (1.6.0)
# Requirement already satisfied: pandas in c:\users\almazt\appdata\local\programs\python\python313\lib\site-packages (from shap) (2.2.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\almazt\appdata\local\programs\python\python313\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\almazt\appdata\local\programs\python\python313\lib\site-packages (from shap) (24.2)
# Collecting slicer==0.0.8 (from shap)
#   Using cached slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting numba (from shap)
#   Using cached numba-0.60.0.tar.gz (2.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [24 lines of output]
#       Traceback (most recent call last):
#         File "c:\Users\Almazt\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#           ~~~~^^
#         File "c:\Users\Almazt\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "c:\Users\Almazt\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "C:\Users\Almazt\AppData\Local\Temp\pip-build-env-cv4ckkj2\overlay\Lib\site-packages\setuptools\build_meta.py", line 334, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Almazt\AppData\Local\Temp\pip-build-env-cv4ckkj2\overlay\Lib\site-packages\setuptools\build_meta.py", line 304, in _get_build_requires
#           self.run_setup()
#           ~~~~~~~~~~~~~~^^
#         File "C:\Users\Almazt\AppData\Local\Temp\pip-build-env-cv4ckkj2\overlay\Lib\site-packages\setuptools\build_meta.py", line 522, in run_setup
#           super().run_setup(setup_script=setup_script)
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Almazt\AppData\Local\Temp\pip-build-env-cv4ckkj2\overlay\Lib\site-packages\setuptools\build_meta.py", line 320, in run_setup
#           exec(code, locals())
#           ~~~~^^^^^^^^^^^^^^^^
#         File "<string>", line 51, in <module>
#         File "<string>", line 48, in _guard_py_ver
#       RuntimeError: Cannot install on Python version 3.13.1; only versions >=3.9,<3.13 are supported.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 12
#       1 # 4. Model Comparison
#       2 # Objective: Evaluate multiple models to identify the best one.
#       3 # Metrics: F1, precision, recall. Use transformers evaluation tools.
#    (...)
#       8
#       9 # %pip install shap
#      10 get_ipython().run_line_magic('pip', 'install shap')
# ---> 12 import shap
#      14 # Use a sample text
#      15 sample_text = "ምርት ከአዲስ ቤተማር እና ብር እንዲቆርብ።"
#
# ModuleNotFoundError: No module named 'shap'
